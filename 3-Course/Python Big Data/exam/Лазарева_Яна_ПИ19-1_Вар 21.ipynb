# %% [markdown]
# Задание 2

# %%
file = pd.read_csv("./exam_data/data2/sp500hst.txt", sep=',',header=None,parse_dates=[0])

# %%
file
# Out:
#                 0    1      2        3       4      5      6
# 0      2009-08-21    A  25.60  25.6100  25.220  25.55  34758
# 1      2009-08-24    A  25.64  25.7400  25.330  25.50  22247
# 2      2009-08-25    A  25.50  25.7000  25.225  25.34  30891
# 3      2009-08-26    A  25.32  25.6425  25.145  25.48  33334
# 4      2009-08-27    A  25.50  25.5700  25.230  25.54  70176
# ...           ...  ...    ...      ...     ...    ...    ...
# 122569 2010-08-13  ZMH  51.72  51.9000  51.380  51.44  14561
# 122570 2010-08-16  ZMH  51.13  51.4700  50.600  51.00  13489
# 122571 2010-08-17  ZMH  51.14  51.6000  50.890  51.21  20498
# 122572 2010-08-19  ZMH  51.63  51.6300  50.170  50.22  18259
# 122573 2010-08-20  ZMH  50.03  50.5500  49.480  49.82  17792
#
# [122574 rows x 7 columns]

# %%
import pandas as pd
import numpy as np

pivot_table = file.pivot(index=0, columns=1,values = 6).fillna(0)
pivot_table

pivot_table.to_csv('result.csv')

# %% [markdown]
# Задание 3

# %%
import re
def spl(a):
    a = a[:-1].split(' ')
    if len(a)>1:
        return [a[0],a[1:-1],a[-1]]
    else:
        return [a[0],[],[]]
import dask.bag as db

people = db.read_text('./exam_data/data3/movies.txt')
p1= people.map(spl).compute()
p1
# Out:
# [['Avatar', [], []],
#  ['Pirates', ['of', 'the', 'Caribbean:', 'At', "World's"], 'End'],
#  ['Spectre', [], []],
#  ['The', ['Dark', 'Knight'], 'Rises'],
#  ['John', [], 'Carter'],
#  ['Spider-Man', [], '3'],
#  ['Tangled', [], []],
#  ['Avengers:', ['Age', 'of'], 'Ultron'],
#  ['Harry', ['Potter', 'and', 'the', 'Half-Blood'], 'Prince'],
#  ['Batman', ['v', 'Superman:', 'Dawn', 'of'], 'Justice'],
#  ['Superman', [], 'Returns'],
#  ['Quantum', ['of'], 'Solace'],
#  ['Pirates', ['of', 'the', 'Caribbean:', 'Dead', "Man's"], 'Chest'],
#  ['The', ['Lone'], 'Ranger'],
#  ['Man', ['of'], 'Steel'],
#  ['The', ['Chronicles', 'of', 'Narnia:', 'Prince'], 'Caspian'],
#  ['The', [], 'Avengers'],
#  ['Pirates', ['of', 'the', 'Caribbean:', 'On', 'Stranger'], 'Tides'],
#  ['Men', ['in', 'Black'], '3'],
#  ['The', ['Hobbit:', 'The', 'Battle', 'of', 'the', 'Five'], 'Armies'],
#  ['The', ['Amazing'], 'Spider-Man'],
#  ['Robin', [], 'Hood'],
#  ['The', ['Hobbit:', 'The', 'Desolation', 'of'], 'Smaug'],
# ...

# %%
m1 = ''
m2 =''
m3 = ''
for i in p1:
    if len(i[0]) > len(m1):
        m1 = i[0]
    if len(i[1]) > len(m2):
        m2 = i[1]

    if len(i[2]) > len(m3):
        m3 = i[2]

print(m1,m2,m3)
# Out:
# Crazy/Beautiful ['Nights', 'of', 'Paranormal', 'Activity', 'With', 'the', 'Devil', 'Inside', 'the', 'Girl', 'With', 'the', 'Dragon'] Extra-Terrestrial

# %%
import re
import dask.bag as db
def spl(a):
    a = a[:-1].split(' ')
    if len(a)>1:
        return [a[0],a[1:-1],a[-1]]
    else:
        return [a[0],[],[]]

    
    people = db.read_text('./exam_data/data3/movies.txt')
    p1= people.map(spl).compute()
       for i in p1:
        if len(i[0]) > len(m1):
            m1 = i[0]
        if len(i[1]) > len(m2):
            m2 = i[1]

        if len(i[2]) > len(m3):
            m3 = i[2]

# %%
@delayed
import dask.bag as db
def fd_mx(p1):
    for i in p1:
        if len(i) > len(m1):
            m1 = i

    return m1

# %%
d1 = fd_mx(p1[0])
d2 = fd_mx(p1[1])
d3 = fd_mx(p1[2])
