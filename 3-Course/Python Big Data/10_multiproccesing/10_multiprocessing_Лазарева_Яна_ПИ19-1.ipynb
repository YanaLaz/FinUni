# %% [markdown]
# # Параллельные вычисления

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 10: Параллельные вычисления
# * https://docs.python.org/3/library/multiprocessing.html

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Посчитайте, сколько раз встречается каждый из символов (заглавные и строчные символы не различаются) в файле `Dostoevskiy Fedor. Prestuplenie i nakazanie - BooksCafe.Net.txt` и в файле `Dostoevskiy Fedor. Igrok - BooksCafe.Net.txt`.

# %%
# %%file count_letters.py
from collections import Counter
def count_letters(file):
    with open(file, 'r', encoding='windows-1251') as fp:
        text = fp.read()
    return Counter(text)

# %%
from count_letters import count_letters

# %%
# %%time
count_letters('data/Dostoevskiy Fedor. Igrok - BooksCafe.Net.txt')
count_letters('data/Dostoevskiy Fedor. Prestuplenie i nakazanie - BooksCafe.Net.txt')

# %% [markdown]
# 2. Решить задачу 1, распараллелив вычисления с помощью модуля `multiprocessing`. Для обработки каждого файла создать свой собственный процесс.

# %%
import multiprocessing as mp

# %%
mp.cpu_count()

# %%
# %%time
if __name__ == "__main__":

    files = ['data/Dostoevskiy Fedor. Igrok - BooksCafe.Net.txt', 
             'data/Dostoevskiy Fedor. Prestuplenie i nakazanie - BooksCafe.Net.txt']

    with mp.Pool(processes=len(files)) as pool:
        counters = pool.map(count_letters, files) # один проц выполняет count_letter с параметром files
        # map - вернет управление, когда все процессы закончат работу и выдаст список результатов

# %%
type(counters)

# %%
counters

# %% [markdown]
# ## Лабораторная работа 10

# %% [markdown]
# 1. Разбейте файл `recipes_full.csv` на несколько (например, 8) примерно одинаковых по объему файлов c названиями `id_tag_nsteps_*.csv`. Каждый файл содержит 3 столбца: `id`, `tag` и `n_steps`, разделенных символом `;`. Для разбора строк используйте `csv.reader`.
#
# __Важно__: вы не можете загружать в память весь файл сразу. Посмотреть на первые несколько строк файла вы можете, написав код, который считывает эти строки.
#
# Подсказка: примерное кол-во строк в файле - 2.3 млн.
#
# Фрагмент одного из файлов, которые должны получиться в результате:
# ```
# id;tag;n_steps
# 137739;60-minutes-or-less;11
# 137739;time-to-make;11
# 137739;course;11
# ```

# %%
import csv

# %%
r_sum = 0
with open('data/recipes_full.csv', 'r') as f:
    incl_col = [1, 5, 6]                          # индексы нужных столбцов
    new_csv = []                              # новый список для нового файла
    reader = csv.reader(f, delimiter=",")
    for row in reader:
        col = list(row[i] for i in incl_col)
        new_csv.append(col)                   # заполняем новый список нужными столбцами
        
        r_sum += len(row[5][2:-2].split("', '"))

# %%
#найдем сколько строк должно быть в каждом файле с учетом количества тэгов
filesize = round(r_sum/8)
filesize
# Out:
# 1767390

# %%
# Разделяем на файлы
count = 0
name = 0
with open('data/recipes_full.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    head = ['id', 'tag', 'n_steps']

    for row in reader:
        if count >= filesize * name:
            # запись заголовков
            name += 1
            writer = csv.writer(open('id_tag_nsteps_' + str(name) + '.csv', 'w+'), delimiter=";")
            writer.writerow(head)

        for tag in row[5][2:-2].split("', '"):
            # запись id, каждого отдельного тега, n_steps
            writer.writerow([row[1], tag, row[6]])
            count += 1

# %% [markdown]
# 2. Напишите функцию, которая принимает на вход название файла, созданного в результате решения задачи 1, считает среднее значение количества шагов для каждого тэга и возвращает результат в виде словаря.

# %%
import pandas as pd

# %%
# %%time
def dict2(name):
    file = pd.read_csv(name, sep=';')
    r = file.groupby(['tag'])['n_steps'].mean()
    rr = r.to_dict()
    return rr
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs

# %%
# %%time
dict2("id_tag_nsteps_3.csv")
# dict2("id_tag_nsteps_4.csv")
# Out:
# CPU times: user 659 ms, sys: 91.6 ms, total: 750 ms
# Wall time: 767 ms
# {'1-day-or-more': 4.554892601431981,
#  '15-minutes-or-less': 5.0599328338930505,
#  '3-steps-or-less': 4.722672846658941,
#  '30-minutes-or-less': 7.64619463161383,
#  '4-hours-or-less': 10.026779422128259,
#  '5-ingredients-or-less': 5.350758356648505,
#  '60-minutes-or-less': 9.403606102635228,
#  'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.': 3.525116082735331,
#  'a1-sauce': 3.506837229819144,
#  'african': 4.394140625,
#  'american': 7.55524861878453,
#  'amish-mennonite': 3.6371951219512195,
#  'angolan': 3.471104946833102,
#  'appetizers': 6.2691420180406965,
#  'apples': 4.887482900136799,
#  'april-fools-day': 3.5055236411842685,
#  'argentine': 3.564487632508834,
#  'artichoke': 3.499778466991582,
#  'asian': 6.449652777777778,
#  'asparagus': 4.072821329088739,
#  'australian': 4.271379703534778,
#  'austrian': 3.563989408649603,
#  'avocado': 3.6176858776946768,
#  'bacon': 4.148622429181218,
#  'baja': 3.599007668019847,
#  'baked-beans': 3.4841129744042365,
#  'baking': 3.67714528462192,
#  'bananas': 4.01483453784709,
#  'bar-cookies': 4.864710365853658,
#  'barbecue': 4.575621546961326,
#  'bass': 3.584224598930481,
#  'bean-soup': 3.511658031088083,
#  'beans': 5.5529761904761905,
#  'beans-side-dishes': 3.5076252723311545,
#  'bear': 3.4895742832319723,
#  'beef': 6.863422291993721,
#  'beef-barley-soup': 3.506470325747434,
#  'beef-crock-pot': 3.4752650176678443,
#  'beef-kidney': 3.453026196928636,
#  'beef-liver': 3.613559322033898,
#  'beef-organ-meats': 3.5867549668874172,
#  'beef-ribs': 3.6023936170212765,
#  'beef-sauces': 3.473318872017354,
#  'beef-sausage': 3.6535806729939604,
#  'beginner-cook': 6.376507840772015,
#  'beijing': 3.4967490247074124,
#  'belgian': 3.6026518391787854,
#  'berries': 5.059132720105125,
#  'beverages': 3.9147098515519567,
#  'birthday': 3.6115107913669067,
#  'biscotti': 3.7062339880444064,
#  'bisques-cream-soups': 4.132883776279254,
#  'black-bean-soup': 3.4972043010752687,
#  'black-beans': 3.967462932454695,
#  'blueberries': 4.040344692518605,
#  'bok-choys': 3.489633877370975,
#  'brazilian': 3.625,
#  'bread-machine': 3.774745417515275,
#  'bread-pudding': 3.5370705244122966,
#  'breads': 7.166625886958649,
#  'breakfast': 6.171059300557527,
#  'vietnamese': 3.6393162393162393,
#  'water-bath': 3.6898537882144438,
#  'wedding': 3.93630849220104,
#  'weeknight': 7.33574529667149,
#  'welsh': 3.5898089171974523,
#  'white-rice': 3.785027185278126,
#  'whitefish': 3.5311559948431457,
#  'whole-chicken': 4.058897770298696,
#  'whole-duck': 3.469777777777778,
#  'whole-turkey': 3.6744505494505493,
#  'wild-game': 3.674051981252663,
#  'wings': 3.685233160621762,
#  'winter': 5.440135426285011,
#  'yams-sweet-potatoes': 3.9592592592592593,
#  'yeast': 5.019366852886406,
#  'zucchini': 3.63640350877193}

# %% [markdown]
# 3. Напишите функцию, которая считает среднее значение количества шагов для каждого тэга по всем файлам, полученным в задаче 1, и возвращает результат в виде словаря. Не используйте параллельных вычислений. При реализации выделите функцию, которая объединяет результаты обработки отдельных файлов. Модифицируйте код из задачи 2 таким образом, чтобы получить результат, имея результаты обработки отдельных файлов. Определите, за какое время задача решается для всех файлов.

# %%
import pandas as pd

# %%
# %%time
def dict3():
    tg = []
    n_st = []
    new = pd.DataFrame()
    for i in range(8):
        file = pd.read_csv('id_tag_nsteps_' + str(i+1) + '.csv', sep=';')
        r = file.groupby(['tag'])['n_steps'].mean()
        rr = r.to_dict()
        
        for k, v in rr.items(): 
            tg.append(k)
            n_st.append(int(v))
            
    
    data = {'tag':tg, 'n_steps':n_st}
    new = pd.DataFrame(data)
    new = new.groupby(['tag'])['n_steps'].mean()
    new = new.to_dict()
    return new

dict3()
# Out:
# CPU times: user 4.79 s, sys: 608 ms, total: 5.39 s
# Wall time: 5.45 s
# {'1-day-or-more': 4.0,
#  '15-minutes-or-less': 4.25,
#  '3-steps-or-less': 4.0,
#  '30-minutes-or-less': 7.0,
#  '4-hours-or-less': 10.0,
#  '5-ingredients-or-less': 5.0,
#  '60-minutes-or-less': 9.0,
#  'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.': 3.0,
#  'a1-sauce': 3.0,
#  'african': 4.0,
#  'american': 7.0,
#  'amish-mennonite': 3.0,
#  'angolan': 3.0,
#  'appetizers': 6.0,
#  'apples': 4.0,
#  'april-fools-day': 3.0,
#  'argentine': 3.0,
#  'artichoke': 3.0,
#  'asian': 6.0,
#  'asparagus': 3.875,
#  'australian': 4.0,
#  'austrian': 3.0,
#  'avocado': 3.0,
#  'bacon': 4.0,
#  'baja': 3.0,
#  'baked-beans': 3.0,
#  'baking': 3.0,
#  'bananas': 3.625,
#  'bar-cookies': 4.0,
#  'barbecue': 4.0,
#  'bass': 3.0,
#  'bean-soup': 3.0,
#  'beans': 5.0,
#  'beans-side-dishes': 3.0,
#  'bear': 3.0,
#  'beef': 6.25,
#  'beef-barley-soup': 3.0,
#  'beef-crock-pot': 3.0,
#  'beef-kidney': 3.0,
#  'beef-liver': 3.0,
#  'beef-organ-meats': 3.0,
#  'beef-ribs': 3.0,
#  'beef-sauces': 3.0,
#  'beef-sausage': 3.0,
#  'beginner-cook': 6.0,
#  'beijing': 3.0,
#  'belgian': 3.0,
#  'berries': 4.5,
#  'beverages': 3.0,
#  'birthday': 3.0,
#  'biscotti': 3.0,
#  'bisques-cream-soups': 4.0,
#  'black-bean-soup': 3.0,
#  'black-beans': 3.0,
#  'blueberries': 3.25,
#  'bok-choys': 3.0,
#  'brazilian': 3.0,
#  'bread-machine': 3.0,
#  'bread-pudding': 3.0,
#  'breads': 6.75,
#  'breakfast': 5.875,
#  'breakfast-casseroles': 3.0,
#  'breakfast-eggs': 3.0,
#  'breakfast-potatoes': 3.0,
#  'brewing': 3.0,
#  'british-columbian': 3.0,
#  'broccoli': 4.0,
#  'broil': 3.875,
#  'brown-bag': 4.0,
#  'brown-rice': 3.0,
#  'brownies': 3.375,
#  'brunch': 6.125,
#  'burgers': 3.0,
#  'cabbage': 3.0,
#  'cajun': 3.0,
#  'cake-fillings-and-frostings': 3.25,
#  'cakes': 6.0,
#  'californian': 3.0,
#  'cambodian': 3.0,
#  'camping': 3.125,
#  'canadian': 4.0,
#  'candy': 4.0,
#  'canning': 3.125,
#  'cantonese': 3.0,
#  'caribbean': 3.375,
#  'carrots': 4.0,
#  'casseroles': 5.0,
#  'catfish': 3.0,
#  'cauliflower': 3.0,
#  'celebrity': 3.0,
#  'central-american': 3.875,
#  'chard': 3.0,
#  'cheese': 6.0,
#  'cheesecake': 4.0,
#  'cherries': 3.0,
#  'chick-peas-garbanzos': 3.0,
#  'chicken': 7.0,
#  'chicken-breasts': 5.0,
#  'chicken-crock-pot': 3.0,
#  'chicken-livers': 3.0,
#  'chicken-stew': 3.0,
#  'chicken-stews': 3.0,
#  'chicken-thighs-legs': 4.0,
#  'chilean': 3.0,
#  'chili': 3.125,
#  'chinese': 4.0,
#  'chinese-new-year': 3.0,
#  'chocolate': 5.875,
#  'chocolate-chip-cookies': 3.0,
#  'chowders': 3.0,
#  'christmas': 5.25,
#  'chutneys': 3.0,
#  'cinco-de-mayo': 3.0,
#  'citrus': 4.0,
#  'clams': 3.0,
#  'clear-soups': 3.0,
#  'cobblers-and-crisps': 3.0,
#  'cocktails': 3.0,
#  'coconut': 3.875,
#  'cod': 3.0,
#  'coffee-cakes': 3.75,
#  'collard-greens': 3.0,
#  'college': 3.0,
#  'colombian': 3.0,
#  'comfort-food': 7.0,
#  'condiments-etc': 4.0,
#  'congolese': 3.0,
#  'cookies-and-brownies': 6.0,
#  'cooking-mixes': 3.0,
#  'copycat': 4.0,
#  'corn': 4.0,
#  'costa-rican': 3.0,
#  'course': 9.0,
#  'crab': 3.0,
#  'cranberry-sauce': 3.0,
#  'crawfish': 3.0,
#  'creole': 3.0,
#  'crock-pot-main-dish': 3.0,
#  'crock-pot-slow-cooker': 4.0,
#  'crusts-pastry-dough-2': 3.0,
#  'cuban': 3.0,
#  'cuisine': 9.0,
#  'cupcakes': 3.125,
#  'curries': 3.75,
#  'czech': 3.0,
#  'dairy-free': 3.0,
#  'danish': 3.0,
#  'deep-fry': 3.5,
#  'deer': 3.0,
#  'dehydrator': 3.0,
#  'desserts': 8.5,
#  'desserts-easy': 3.0,
#  'desserts-fruit': 3.0,
#  'diabetic': 4.125,
#  'dietary': 8.0,
#  'dinner-party': 8.0,
#  'dips': 3.75,
#  'dips-lunch-snacks': 3.0,
#  'dips-summer': 3.0,
#  'drop-cookies': 4.0,
#  'duck': 3.0,
#  'duck-breasts': 3.0,
#  'dutch': 3.0,
#  'easter': 4.0,
#  'easy': 7.0,
#  'ecuadorean': 3.0,
#  'egg-free': 4.0,
#  'eggplant': 3.0,
#  'eggs': 5.0,
#  'eggs-breakfast': 3.0,
#  'eggs-dairy': 7.0,
#  'egyptian': 3.0,
#  'elbow-macaroni': 3.875,
#  'elk': 3.0,
#  'english': 4.0,
#  'equipment': 8.0,
#  'ethiopian': 3.0,
#  'european': 7.75,
#  'fall': 5.0,
#  'fathers-day': 3.0,
#  'filipino': 3.0,
#  'fillings-and-frostings-chocolate': 3.0,
#  'finger-food': 5.0,
#  'finnish': 3.0,
#  'fish': 5.0,
#  'flat-shapes': 3.0,
#  'food-processor-blender': 4.0,
#  'for-1-or-2': 5.0,
#  'for-large-groups': 7.0,
#  'for-large-groups-holiday-event': 3.0,
#  'free-of-something': 5.0,
#  'freezer': 3.875,
#  'french': 4.0,
#  'freshwater-fish': 3.0,
#  'from-scratch': 4.0,
#  'frozen-desserts': 3.75,
#  'fruit': 7.0,
#  'fudge': 3.0,
#  'garnishes': 3.0,
#  'gelatin': 3.0,
#  'georgian': 3.0,
#  'german': 3.875,
#  'gifts': 5.0,
#  'gluten-free': 4.0,
#  'goose': 3.0,
#  'grains': 5.0,
#  'granola-and-porridge': 3.0,
#  'grapes': 3.0,
#  'greek': 4.0,
#  'green-yellow-beans': 3.0,
#  'greens': 4.0,
#  'grilling': 4.0,
#  'ground-beef': 5.0,
#  'guatemalan': 3.0,
#  'gumbo': 3.0,
#  'halibut': 3.0,
#  'halloween': 3.0,
#  'halloween-cakes': 3.0,
#  'halloween-cocktails': 3.0,
#  'halloween-cupcakes': 3.0,
#  'ham': 3.625,
#  'ham-and-bean-soup': 3.0,
#  'hand-formed-cookies': 4.0,
#  'hanukkah': 3.0,
#  'hawaiian': 3.0,
#  'healthy': 6.875,
#  'healthy-2': 6.0,
#  'heirloom-historical': 4.875,
#  'heirloom-historical-recipes': 3.0,
#  'herb-and-spice-mixes': 3.0,
#  'hidden-valley-ranch': 3.0,
#  'high-calcium': 4.0,
#  'high-fiber': 3.0,
#  'high-in-something': 5.0,
#  'high-in-something-diabetic-friendly': 3.0,
#  'high-protein': 4.5,
#  'holiday-event': 8.0,
#  'honduran': 3.0,
#  'hunan': 3.0,
#  'hungarian': 3.0,
#  'ice-cream': 3.0,
#  'icelandic': 3.0,
#  'independence-day': 3.875,
#  'indian': 4.0,
#  'indonesian': 3.0,
#  'inexpensive': 6.25,
#  'infant-baby-friendly': 3.0,
#  'iranian-persian': 3.0,
#  'iraqi': 3.0,
#  'irish': 3.0,
#  'irish-st-patricks-day': 3.0,
#  'italian': 5.0,
#  'jams-and-preserves': 3.0,
#  'japanese': 3.0,
#  'jellies': 3.0,
#  'jewish-ashkenazi': 3.0,
#  'jewish-sephardi': 3.0,
#  'kid-friendly': 6.875,
#  'kiwifruit': 3.0,
#  'korean': 3.0,
#  'kosher': 4.0,
#  'kwanzaa': 3.0,
#  'labor-day': 3.0,
#  'lactose': 4.0,
#  'lamb-sheep': 3.875,
#  'lamb-sheep-main-dish': 3.0,
#  'laotian': 3.0,
#  'lasagna': 3.875,
#  'lasagne': 3.0,
#  'lebanese': 3.0,
#  'leftovers': 3.0,
#  'lemon': 4.0,
#  'lentils': 3.0,
#  'less_thansql:name_topics_of_recipegreater_than': 3.0,
#  'lettuces': 3.0,
#  'libyan': 3.0,
#  'lime': 3.0,
#  'lobster': 3.0,
#  'long-grain-rice': 3.125,
#  'low-calorie': 6.0,
#  'low-carb': 7.0,
#  'low-cholesterol': 6.0,
#  'low-fat': 5.25,
#  'low-in-something': 7.875,
#  'low-protein': 6.0,
#  'low-saturated-fat': 6.0,
#  'low-sodium': 7.0,
#  'lunch': 6.0,
#  'macaroni-and-cheese': 3.0,
#  'mahi-mahi': 3.0,
#  'main-dish': 9.0,
#  'main-dish-beef': 3.0,
#  'main-dish-chicken': 3.0,
#  'main-dish-pasta': 3.0,
#  'main-dish-pork': 3.0,
#  'main-dish-seafood': 3.0,
#  'main-ingredient': 9.0,
#  'malaysian': 3.0,
#  'mango': 3.0,
#  'manicotti': 3.0,
#  'mardi-gras-carnival': 3.0,
#  'marinades-and-rubs': 3.0,
#  'marinara-sauce': 3.0,
#  'mashed-potatoes': 3.0,
#  'meat': 8.125,
#  'meatballs': 3.0,
#  'meatloaf': 3.0,
#  'medium-grain-rice': 3.0,
#  'melons': 3.0,
#  'memorial-day': 3.0,
#  'mexican': 5.0,
#  'micro-melanesia': 3.0,
#  'microwave': 3.875,
#  'middle-eastern': 4.0,
#  'middle-eastern-main-dish': 3.0,
#  'midwestern': 4.0,
#  'mixer': 4.0,
#  'mongolian': 3.0,
#  'moose': 3.0,
#  'moroccan': 3.0,
#  'mothers-day': 3.0,
#  'muffins': 4.0,
#  'mushroom-soup': 3.0,
#  'mushrooms': 4.0,
#  'mussels': 3.0,
#  'namibian': 3.0,
#  'native-american': 3.0,
#  'nepalese': 3.0,
#  'new-years': 4.0,
#  'new-zealand': 3.0,
#  'nigerian': 3.0,
#  'no-cook': 3.125,
#  'no-shell-fish': 3.0,
#  'non-alcoholic': 3.0,
#  'north-american': 8.0,
#  'northeastern-united-states': 4.0,
#  'norwegian': 3.0,
#  'novelty': 4.0,
#  'number-of-servings': 7.0,
#  'nut-free': 3.0,
#  'nuts': 5.0,
#  'oamc-freezer-make-ahead': 4.75,
#  'oatmeal': 3.0,
#  'oaxacan': 3.0,
#  'occasion': 9.0,
#  'octopus': 3.0,
#  'omelets-and-frittatas': 3.0,
#  'one-dish-meal': 6.5,
#  'onions': 4.5,
#  'ontario': 3.0,
#  'orange-roughy': 3.0,
#  'oranges': 3.0,
#  'oven': 8.0,
#  'oysters': 3.0,
#  'pacific-northwest': 3.0,
#  'pakistani': 3.0,
#  'palestinian': 3.0,
#  'pancakes-and-waffles': 4.0,
#  'papaya': 3.0,
#  'passover': 3.0,
#  'pasta': 6.0,
#  'pasta-elbow-macaroni': 3.0,
#  'pasta-rice-and-grains': 7.0,
#  'pasta-rice-and-grains-elbow-macaroni': 3.0,
#  'pasta-salad': 3.0,
#  'pasta-shells': 3.0,
#  'peaches': 3.0,
#  'peanut-butter': 3.0,
#  'pears': 3.0,
#  'penne': 3.125,
#  'pennsylvania-dutch': 3.0,
#  'peppers': 4.0,
#  'perch': 3.0,
#  'peruvian': 3.0,
#  'pheasant': 3.0,
#  'pickeral': 3.0,
#  'picnic': 4.75,
#  'pies': 4.0,
#  'pies-and-tarts': 5.0,
#  'pineapple': 3.25,
#  'pitted-fruit': 4.0,
#  'pizza': 4.0,
#  'plums': 3.0,
#  'polish': 3.0,
#  'polynesian': 3.0,
#  'pork': 6.0,
#  'pork-chops': 3.875,
#  'pork-crock-pot': 3.0,
#  'pork-loin': 3.0,
#  'pork-loins': 3.75,
#  'pork-loins-roast': 3.0,
#  'pork-ribs': 3.0,
#  'pork-sausage': 4.0,
#  'portuguese': 3.0,
#  'pot-pie': 3.0,
#  'pot-roast': 3.0,
#  'potatoes': 5.0,
#  'potluck': 5.0,
#  'poultry': 7.0,
#  'preparation': 9.0,
#  'prepared-potatoes': 3.0,
#  'presentation': 7.0,
#  'pressure-canning': 3.0,
#  'pressure-cooker': 3.0,
#  'puddings-and-mousses': 4.0,
#  'puerto-rican': 3.0,
#  'pumpkin': 3.0,
#  'pumpkin-bread': 3.0,
#  'punch': 3.0,
#  'quail': 3.0,
#  'quebec': 3.0,
#  'quiche': 3.0,
#  'quick-breads': 4.75,
#  'rabbit': 3.0,
#  'ragu-recipe-contest': 3.0,
#  'ramadan': 3.0,
#  'raspberries': 3.125,
#  'ravioli-tortellini': 3.0,
#  'refrigerator': 4.0,
#  'reynolds-wrap': 3.0,
#  'rice': 5.0,
#  'roast': 3.625,
#  'roast-beef': 3.625,
#  'roast-beef-comfort-food': 3.0,
#  'roast-beef-main-dish': 3.0,
#  'rolled-cookies': 3.125,
#  'rolls-biscuits': 4.0,
#  'romantic': 5.0,
#  'rosh-hashana': 3.0,
#  'rosh-hashanah': 3.0,
#  'russian': 3.0,
#  'salad-dressings': 3.0,
#  'salads': 4.75,
#  'salmon': 4.0,
#  'salsas': 3.0,
#  'saltwater-fish': 4.0,
#  'sandwiches': 4.0,
#  'sauces': 4.0,
#  'saudi-arabian': 3.0,
#  'savory': 5.625,
#  'savory-pies': 4.0,
#  'savory-sauces': 3.0,
#  'scallops': 3.0,
#  'scandinavian': 3.25,
#  'scones': 3.0,
#  'scottish': 3.0,
#  'seafood': 6.0,
#  'seasonal': 6.0,
#  'served-cold': 4.125,
#  'served-hot': 6.0,
#  'served-hot-new-years': 3.0,
#  'shakes': 3.0,
#  'shellfish': 5.0,
#  'short-grain-rice': 3.0,
#  'shrimp': 4.0,
#  'shrimp-main-dish': 3.0,
#  'side-dishes': 6.0,
#  'side-dishes-beans': 3.0,
#  'simply-potatoes': 3.0,
#  'simply-potatoes2': 3.0,
#  'small-appliance': 5.0,
#  'smoker': 3.0,
#  'smoothies': 3.0,
#  'snacks': 4.25,
#  'snacks-kid-friendly': 3.0,
#  'snacks-sweet': 3.0,
#  'sole-and-flounder': 3.0,
#  'somalian': 3.0,
#  'soul': 3.0,
#  'soups-stews': 5.25,
#  'sourdough': 3.0,
#  'south-african': 3.0,
#  'south-american': 3.125,
#  'south-west-pacific': 4.0,
#  'southern-united-states': 5.0,
#  'southwestern-united-states': 4.0,
#  'soy-tofu': 3.125,
#  'spaghetti': 3.875,
#  'spaghetti-sauce': 3.0,
#  'spanish': 3.0,
#  'spicy': 5.0,
#  'spinach': 4.0,
#  'spreads': 3.0,
#  'spring': 4.0,
#  'squash': 4.0,
#  'squid': 3.0,
#  'st-patricks-day': 3.0,
#  'steak': 3.125,
#  'steaks': 3.0,
#  'steam': 3.0,
#  'stews': 4.0,
#  'stews-poultry': 3.0,
#  'stir-fry': 4.0,
#  'stocks': 3.0,
#  'stove-top': 7.0,
#  'strawberries': 4.0,
#  'stuffings-dressings': 3.0,
#  'sudanese': 3.0,
#  'sugar-cookies': 3.0,
#  'summer': 5.0,
#  'super-bowl': 3.0,
#  'superbowl': 3.75,
#  'swedish': 3.0,
#  'sweet': 5.625,
#  'sweet-sauces': 3.0,
#  'swiss': 3.0,
#  'szechuan': 3.0,
#  'tarts': 3.0,
#  'taste-mood': 8.0,
#  'technique': 5.0,
#  'tempeh': 3.0,
#  'tex-mex': 3.125,
#  'thai': 3.0,
#  'thanksgiving': 4.375,
#  'tilapia': 3.0,
#  'time-to-make': 9.0,
#  'to-go': 6.0,
#  'toddler-friendly': 4.0,
#  'tomatoes': 4.0,
#  'tropical-fruit': 4.0,
#  'trout': 3.0,
#  'tuna': 3.0,
#  'turkey': 4.0,
#  'turkey-breasts': 3.0,
#  'turkey-burgers': 3.0,
#  'turkish': 3.0,
#  'unprocessed-freezer': 3.0,
#  'valentines-day': 4.0,
#  'veal': 3.0,
#  'vegan': 5.0,
#  'vegetables': 8.0,
#  'vegetarian': 7.0,
#  'veggie-burgers': 3.0,
#  'venezuelan': 3.0,
#  'very-low-carbs': 5.0,
#  'vietnamese': 3.0,
#  'water-bath': 3.0,
#  'wedding': 3.0,
#  'weeknight': 7.0,
#  'welsh': 3.0,
#  'white-rice': 3.0,
#  'whitefish': 3.0,
#  'whole-chicken': 3.75,
#  'whole-duck': 3.0,
#  'whole-turkey': 3.0,
#  'wild-game': 3.0,
#  'wings': 3.0,
#  'winter': 5.0,
#  'yams-sweet-potatoes': 3.625,
#  'yeast': 5.0,
#  'zucchini': 3.0}

# %% [markdown]
# 4. Решите задачу 3, распараллелив вычисления с помощью модуля `multiprocessing`. Для обработки каждого файла создайте свой собственный процесс. Определите, за какое время задача решается для всех файлов.

# %%
import multiprocessing as mp

# %%
# %%file dict3.py
import pandas as pd
def dict3(name):
    file = pd.read_csv(name, sep=';')
    r = file.groupby(['tag'])['n_steps'].mean()
    rr = r.to_dict()
    return rr
# Out:
# Overwriting dict3.py

# %%
from dict3 import dict3

# %%
# %%time
if __name__ == "__main__":

    files = ["id_tag_nsteps_1.csv", 
             "id_tag_nsteps_2.csv",
            "id_tag_nsteps_3.csv",
            "id_tag_nsteps_4.csv",
            "id_tag_nsteps_5.csv",
            "id_tag_nsteps_6.csv",
            "id_tag_nsteps_7.csv",
            "id_tag_nsteps_8.csv"]

    with mp.Pool(processes=len(files)) as pool:
        res = pool.map(dict3, files) # один проц выполняет count_letter с параметром files
        # map - вернет управление, когда все процессы закончат работу и выдаст список результатов
        tg = []
        n_st = []
        count = 0
        for i in range(8):
            for k, v in res[i].items():
                tg.append(k)
                n_st.append(int(v))
            
        data = {'tag':tg, 'n_steps':n_st}
        new = pd.DataFrame(data)
        new = new.drop(labels = [0],axis = 0)
        new = new.groupby(['tag'])['n_steps'].mean()
        new = new.to_dict()
        print(new)
# Out:
# {'1-day-or-more': 4.0, '15-minutes-or-less': 4.25, '3-steps-or-less': 4.0, '30-minutes-or-less': 7.0, '4-hours-or-less': 10.0, '5-ingredients-or-less': 5.0, '60-minutes-or-less': 9.0, 'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.': 3.0, 'a1-sauce': 3.0, 'african': 4.0, 'american': 7.0, 'amish-mennonite': 3.0, 'angolan': 3.0, 'appetizers': 6.0, 'apples': 4.0, 'april-fools-day': 3.0, 'argentine': 3.0, 'artichoke': 3.0, 'asian': 6.0, 'asparagus': 3.875, 'australian': 4.0, 'austrian': 3.0, 'avocado': 3.0, 'bacon': 4.0, 'baja': 3.0, 'baked-beans': 3.0, 'baking': 3.0, 'bananas': 3.625, 'bar-cookies': 4.0, 'barbecue': 4.0, 'bass': 3.0, 'bean-soup': 3.0, 'beans': 5.0, 'beans-side-dishes': 3.0, 'bear': 3.0, 'beef': 6.25, 'beef-barley-soup': 3.0, 'beef-crock-pot': 3.0, 'beef-kidney': 3.0, 'beef-liver': 3.0, 'beef-organ-meats': 3.0, 'beef-ribs': 3.0, 'beef-sauces': 3.0, 'beef-sausage': 3.0, 'beginner-cook': 6.0, 'beijing': 3.0, 'belgian': 3.0, 'berries': 4.5, 'beverages': 3.0, 'birthday': 3.0, 'biscotti': 3.0, 'bisques-cream-soups': 4.0, 'black-bean-soup': 3.0, 'black-beans': 3.0, 'blueberries': 3.25, 'bok-choys': 3.0, 'brazilian': 3.0, 'bread-machine': 3.0, 'bread-pudding': 3.0, 'breads': 6.75, 'breakfast': 5.875, 'breakfast-casseroles': 3.0, 'breakfast-eggs': 3.0, 'breakfast-potatoes': 3.0, 'brewing': 3.0, 'british-columbian': 3.0, 'broccoli': 4.0, 'broil': 3.875, 'brown-bag': 4.0, 'brown-rice': 3.0, 'brownies': 3.375, 'brunch': 6.125, 'burgers': 3.0, 'cabbage': 3.0, 'cajun': 3.0, 'cake-fillings-and-frostings': 3
# CPU times: user 37.7 ms, sys: 79.4 ms, total: 117 ms
# Wall time: 4.48 s

# %% [markdown]
# 5. Решите задачу 3, распараллелив вычисления с помощью модуля `multiprocessing`. Создайте фиксированное количество процессов (равное половине количества ядер на компьютере). При помощи очереди `multiprocessing.queue` передайте названия файлов для обработки процессам и при помощи другой очереди заберите от них ответы.

# %%
import multiprocessing as mp

# %%
mp.cpu_count()
# Out:
# 4

# %%
# %%file dict4.py
from multiprocessing import Pool, Queue
import csv
import pandas as pd


def f(q_in, q_out):
    while True: 
        link = q_in.get()
        q_out.put(dict4(link))
        
def dict4(name):
    file = pd.read_csv(name, sep=';')
    r = file.groupby(['tag'])['n_steps'].mean()
    rr = r.to_dict()
    return rr
# Out:
# Overwriting dict4.py

# %%
# %%time
import multiprocessing as mp
from dict4 import f


if __name__ == "__main__":
    
    files = ["id_tag_nsteps_1.csv", 
             "id_tag_nsteps_2.csv",
            "id_tag_nsteps_3.csv",
            "id_tag_nsteps_4.csv",
            "id_tag_nsteps_5.csv",
            "id_tag_nsteps_6.csv",
            "id_tag_nsteps_7.csv",
            "id_tag_nsteps_8.csv"]
    N = 2
    in_q = mp.Queue()
    out_q = mp.Queue()
    res = []

    for file in files:
        in_q.put(file)
        
    processes = []
    for i in range(2):
        process = mp.Process(target = f, args=(in_q, out_q))
        processes.append(process)
        
    for process in processes:
        process.start()

        
    for _ in files:
        result = out_q.get()
        res.append(result)
        
    
    tg = []
    n_st = []
    count = 0
    for i in range(8):
        for k, v in res[i].items():
            tg.append(k)
            n_st.append(int(v))

    data = {'tag':tg, 'n_steps':n_st}
    new = pd.DataFrame(data)
    new = new.drop(labels = [0],axis = 0)
    new = new.groupby(['tag'])['n_steps'].mean()
    new = new.to_dict()
    print(new)
        
print(res)
# Out:
# [{'1-day-or-more': 4.4613270514330585, '15-minutes-or-less': 4.944268524382521, '3-steps-or-less': 4.693985544656686, '30-minutes-or-less': 7.589451799978116, '4-hours-or-less': 10.020288817281298, '5-ingredients-or-less': 5.3101368250698835, '60-minutes-or-less': 9.413485776017286, 'Throw the ultimate fiesta with this sopaipillas recipe from Food.com.': 3.5100087032201914, 'a1-sauce': 3.563061137238136, 'african': 4.4886929858183215, 'american': 7.762587635436584, 'amish-mennonite': 3.4982817869415808, 'angolan': 3.5143741707209197, 'appetizers': 6.221261337270618, 'apples': 4.8714744734023565, 'april-fools-day': 3.4729041222788326, 'argentine': 3.592967032967033, 'artichoke': 3.4732547597461467, 'asian': 6.379743522638053, 'asparagus': 4.009437833401724, 'australian': 4.1521655806822535, 'austrian': 3.6343574210298573, 'avocado': 3.5505569837189372, 'bacon': 4.1232208214721435, 'baja': 3.5275891341256367, 'baked-beans': 3.5220713073005094, 'baking': 3.635058721183123, 'bananas': 3.9783549783549783, 'bar-cookies': 4.861854159032613, 'barbecue': 4.632065016623568, 'bass': 3.4