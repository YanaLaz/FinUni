# %%
class Apparat:
    def __init__(self, name, price, c_vlad, c_proiz):
        self.name = name
        self.price = price
        self.c_vlad = c_vlad
        self.c_proiz = c_proiz
        
    def info(self):
        print(f"Имя: {self.name}, Цена: {self.price}, Страна владелец: {self.c_vlad}, Страна производитель: {self.c_proiz}")
        
#a= Apparat('airbus 500',2000000000,'aeroflot','usa/ads')

class Plane(Apparat):
    def __init__(self, name, price, speed, type_, type_vor, fly, max_fly, fuel, max_fuel, end_fuel, c_vlad, c_proiz):
        super().__init__(name, price, c_vlad, c_proiz)
        self.speed = speed
        self.type_ =type_
        self.type_vor = type_vor
        self.max_fly = max_fly
        self.fly = fly
        self.fuel =fuel
        self.max_fuel = max_fuel
        self.end_fuel = end_fuel
        
    def info(self):
        print(f"Имя: {self.name}, Цена: {self.price}, Cкорость: {self.speed}, тип самолета: {self.type_}, тип вооружения: {self.type_vor}, максимальная высота полета: {self.max_fly}, высота полета: {self.fly}, запас топлива в баке: {self.fuel}, максимальный запас топлива: {self.max_fuel}, расход топлива: {self.end_fuel}, Страна владелец: {self.c_vlad}, Страна производитель: {self.c_proiz}")
        
        
    def speed(self):
        return self.speed
    
    def fly(self):
        return self.max_fly
    
    def time1(self):
        path = (int(self.fuel)*100)/int(self.end_fuel)
        time = path/int(self.speed)
        return time
    
    def polet2(self, rasst):
        d = (int(self.fuel)*100)/int(self.end_fuel)
        if d==rasst:
            print('Полет возможен')
        else:
            print('Полет невозможен')
            
    def cel3(self):
        if self.type_.lower() == 'бомбардировщик':
            print('Наземные')
        elif self.type_.lower() == 'истребитель':
            print('Любые летательные аппараты')
        elif self.type_.lower() == 'штурмовик':
            print('Наземные и летательные аппараты')
        elif self.type_.lower() == 'пассажирский':
            print('Никакие')
        else:
            print('Измените тип вашего судна: бомбардировщик, истребитель, штурмовик, пассажирский')
            
    def abil4(self):
        if gas>0: 
            if gas-consuming<=0: 
                if (speed*time)>=distance: 
                    print (name +" смогет пролететь такое расстояние") 
                    return 1 
                else: 
                    print ("самолетик, который не смог долететь до пункта назначения") 
                    return 1 
            return self.gaspik (name,gas - consuming, consuming, time+1,speed)
        
        p = int(input('Введите расстояние для сравнения: '))
        path = ((int(self.max_fuel)*100)/int(self.end_fuel))/int(self.speed)
        if path<p:
            print('Не долетит')
        else:
            print('Долетит')
    
    
p = Plane('су-35',2000000000, 900, 'военный','нет', '12000', '14000','4000','11500','319', 'aeroflot','usa/ads')
#p.info()
#p.time1()
#p.polet2(40)
#p.cel3()
#p.abil4()


class Helic(Apparat):
    def __init__(self, name, price, gruz, passang, vints, type_, fly, coord, c_vlad, c_proiz):
        super().__init__(name, price, c_vlad, c_proiz)
        self.gruz = gruz
        self.passang = passang
        self.vints = vints
        self.type_ = type_
        self.fly = fly
        self.coord = coord
        
    def info(self):
        print(f"Имя: {self.name}, Цена: {self.price}, грузоподъемность: {self.gruz}, количество членов экипажа: {self.passang}, количество винтов: {self.vints}, тип объекта: {self.type_}, высота полета: {self.fly}, место расположение объекта: {self.coord},  Страна владелец: {self.c_vlad}, Страна производитель: {self.c_proiz}")
 
    
    def count1(self):
        n = int(input('масса груза: '))
        k = int(input('количество полетов: '))
        v = n/k
        if v==1:
            print(f'Транспортный вертолет с грузоподъемностью >= {n}')
        else:
            print(f'{k} вертолётов, гразоподъемность должна быть больше {v} и меньше {n}')
            

class PVO:
    def __init__(self, name, height, snarad, people):
        self.name = name
        self.height = height
        self.snarad = snarad
        self.people = people
        
        
    def info(self):
        print(f'Имя {self.name}, Высота поражения: {self.height}, Количество снарядов: {self.snarad}, количество людей в расчете: {self.people}')
        
class Racket(PVO):
    def __init__(self, name, dist, height, speed, snarad, move, sp_move, people):
        super().__init__(name,height, snarad, people)
        self.dist = dist
        self.speed = speed
        self.move = move
        self.sp_move = sp_move
        
    def info(self):
        print(f'Имя {self.name}, Дистанция: {self.dist}, Высота поражения: {self.height}, Количество ракет в установке: {self.snarad}, Стационарное или перемещаемое: {self.move}, скорость перемещения: {self.sp_move}, количество людей в расчете: {self.people}')
        
    def fight(self,la):
        if int(self.speed)> int(la.speed):
            print('Поражение летательного объекта возможно')
        else:
            print('Поражение летательного объекта невозможно')


r = Racket('racket','2000','4000','800','100','стационарное','20','30')
#r.fight(p)
        
        
class Zenit(PVO):
    def __init__(self, name, height, snarad, kalibr, stvol, people):
        super().__init__(name,height, snarad, people)
        self.kalibr = kalibr
        self.stvol = stvol
    
    def info(self):
        print(f'Имя {self.name}, Высота поражения: {self.height}, Количество снарядов: {self.snarad}, калибр: {self.kalibr}, количество стволов: {self.stvol}, количество людей в расчете: {self.people}')
        
    def fight_v(self,la):
        if int(self.height) > int(la.fly):
            print('Поражение летательного объекта возможно')
        else:
            print('Поражение летательного объекта невозможно')

z = Zenit('zenit', '20000','200','a23','30','10')
z.fight_v(pz.fight_v(p'z.fight_v(pz.fight_v(p')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-e3c0f718a8f4> in <module>
#      86 #p.polet2(40)
#      87 #p.cel3()
# ---> 88 p.gaspik(4000,319,2000,120,3000)
#      89
#      90
#
# <ipython-input-32-e3c0f718a8f4> in gaspik(self, gas, consuming, distance, time, speed)
#      71                     print ("не долетит")
#      72                     return 1
# ---> 73         return self.gaspik(gas - consuming, consuming, time+1,speed)
#      74
#      75         #p = int(input('Введите расстояние для сравнения: '))
#
# TypeError: gaspik() missing 1 required positional argument: 'speed'
