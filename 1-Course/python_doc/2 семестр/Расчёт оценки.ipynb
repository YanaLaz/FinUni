# %%
import datetime

class Inter():        
    def vvod():
        File=open('new.txt', 'w') 
        title = input('Введите название дисциплины: ')
        print('** '+ str(title)+' **')
        File.write(str(title)+'\n')
        File.write('Фамилия             Номер группы        Кассы   Модули  Рекурсия   Тест1   Тест2   Тест3   Контр. раб.   Итог')
        File.close()
        def new():
            File=open('new.txt', 'a') 
            name= input('Введите фамилию студента: ')
            group= input('Введите номер группы(пример ПИ19-1): ')
            if len(name)<20:
                stolb = int(20-len(name))
            if len(group)<20:
                stolb_g=int(20-len(group))
            print('** Вводим даты практики по Классам: выполнение, защита **')
            def prak():
                done = input('Введите дату выполнения(ПРИМЕР 12 января 2020 надо ввести так- 2020.01.12): ')
                zac = input('Введите дату защиты(ПРИМЕР 12 января 2020 надо ввести так- 2020.01.12): ')
                done=done.split('.')
                zac=zac.split('.')
                ddone= datetime.date(int(done[0]),int(done[1]),int(done[2]))
                dzac= datetime.date(int(zac[0]),int(zac[1]),int(zac[2]))
                c = str(dzac-ddone)
                z = int(c.split()[0])
                if z < 8:
                    mark = 3
                else:
                    mark= 2
                return mark
            cl = prak()
            print('** Вводим даты практики по Модулям: выполнение, защита **')
            mod = prak()
            print('** Вводим даты практики по Рекурсиям: выполнение, защита **')
            rec = prak()
            print('** Вводим результаты за 3 теста **')
            t1 = input('Введите результат за 1 тест: ')
            t2 = input('Введите результат за 2 тест: ')
            t3 = input('Введите результат за 3 тест: ')
            kr = input('Введите рузельтат за контр. раб.: ')
            itog = int(cl)+ int(mod)+int(rec)+int(t1)+int(t2)+int(t2)+int(t3)+int(kr)
            File.write('\n'+str(name)+str(' '*stolb)+str(group)+str(' '*stolb_g)+str()+str(cl)+str(' '*7)+str(mod)+str(' '*7)+str(rec)+(' '*10)+str(t1)+str('       ')+str(t2)+str('       ')+str(t3)+str('       ')+str(kr)+str(' '*14)+str(itog))
            x=input("Хотите ввести еще ученика? Да/нет ")
            if x.lower()=='да':
                File.close()
                return new()
            else:
                File.close()
                return print('Хорошо. Вся информация уже экспортирована в новый файл под именем new.txt. Можете проверить данные и не забудьте открыть файл в полноэкранном режиме, чтобы столбцы не сместились. Спасибо!')
        new()
            
class Info():
    def inf():
        f = open('new.txt', 'r') 
        for row in f:
            print(row)
        



vopros = int(input('Хотите заполнить таблицу - 1 \nХотите увидеть всю таблицу - 2 \n'))
if vopros == 1:
    Inter.vvod()
else:
    try:
        Info.inf()
    except Exception:
        x = input('Похоже файл еще не создан. Хотите создать? да/нет ')
        if x.lower()=='да':
            Inter.vvod()
        else:
            print('Выход из программы')
# Out:
# Хотите заполнить таблицу - 1
# Хотите увидеть всю таблицу - 2
# 2
# Алгоритмы и структуры данных в языке Python
#
# Фамилия             Номер группы        Кассы   Модули  Рекурсия   Тест1   Тест2   Тест3   Контр. раб.   Итог
#
# Лазарева            ПИ19-1              3       3       3          2       2       2       5              22
#
# Крылов              ПИ19-1              3       3       3          1       1       0       3              15
