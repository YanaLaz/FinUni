# %%
def m_v():
    try:
        r1 = int(input('Количество строк в матрице: '))
        c1 = int(input('Количество столбцов в матрице: ')) 
        A = []
        print('Вводим элементы матрицы А')
        for i in range(r1) :
            A.append([])
            for j in range(c1) :
                A[i].append(int(input()))        
        print('A = ')
        for q in A :
            print(q)

        v = []
        x = int(input('Элементов в векторе: '))
        print('Вводим элементы вектора')
        for k in range(x):
            v.append(int(input()))
        print('V =', v)
    
    
        s=0     #сумма
        t=[]    #временная матрица
        C=[]    #конечная матрица
        v1 = len(v)

        #проверка и перемножение
        if c1 != len(v):
            print('матрица не может быть умножена на вектор')
        else:
            for z in range(0,r1):
                for i in range(0,c1):
                    s = A[z][i]*v[i]
                    t.append(s)
                    s=0
                C.append(t) 
                t=[]
            print('результат')
            for i in C:
                print(i)
    except Exception as e:
        print("Ошибка:", e) 
            
def m_ch():
    try:
        r1 = int(input('Количество строк в матрице: '))
        c1 = int(input('Количество столбцов в матрице: ')) 
        print('Вводим элементы матрицы A')
        #Вводим элементы матрицы A
        A = []
        for i in range(r1) :
            A.append([])
            for j in range(c1) :
                A[i].append(int(input()))        
        print('A = ')
        for q in A :
            print(q)

        x = int(input('Введите число: '))

        #умножение    
        s=0     #сумма
        t=[]    #временная матрица
        C=[]    #конечная матрица
        r1=len(A) #количество строк в первой матрице
        c1=len(A[0]) #Количество столбцов в 1    
        for z in range(0,r1):
            for i in range(0,c1):
                s=A[z][i]*x
                t.append(s)
                s=0
            C.append(t)
            t=[] 
            print('результат')
            for i in C:
                print(i)
    except Exception as e:
        print("Ошибка:", e)
        
def m_m():
    try: 
        #Вводим размер матриц
        r1 = int(input('Количество строк в матрице 1: '))
        c1 = int(input('Количество столбцов в матрице 1: ')) 
        r2 = int(input('Количество строк в матрице 2: '))
        c2 = int(input('Количество столбцов в матрице 2: '))

        print('Вводим элементы матрицы A')
        #Вводим элементы матрицы A
        A = []
        for i in range(r1) :
            A.append([])
            for j in range(c1) :
                A[i].append(int(input()))        
        print('A = ')
        for q in A :
            print(q)
        print('Вводим элементы матрицы B')
        #Вводим элементы матрицы B
        B = []
        for q in range(r2) :
            B.append([])
            for w in range(c2) :
                B[q].append(int(input()))
        print('B = ')
        for q in B :
            print(q)

        #Умножение
        s=0     #сумма
        t=[]    #временная матрица
        C=[]    #конечная матрица
        if c1!=r2:     
            print("Матрицы не могут быть перемножены")        
        else:
            r1=len(A) #количество строк в первой матрице
            c1=len(A[0]) #Количество столбцов в 1   
            r2=c1           #и строк во 2ой матрице
            c2=len(B[0])  # количество столбцов во 2ой матрице
            for z in range(0,r1):
                for j in range(0,c2):
                    for i in range(0,c1):
                        s=s+A[z][i]*B[i][j]
                    t.append(s)
                    s=0
                C.append(t)
                t=[]  
            print('Результат: ')
            for i in C:
                print(i)
    except Exception as e:
        print("Ошиб1ка:", e)


print('Выбери:')
print('1 - матрица на число')
print('2 - матрица на вектор')
print('3 - матрица на матрицу')
x = int(input())
if x == 1:
    m_ch()
elif x == 2:
    m_v()
elif x == 3:
    m_m()
# Out:
# Выбери:
# 1 - матрица на число
# 2 - матрица на вектор
# 3 - матрица на матрицу
# 3
# Количество строк в матрице 1: 2
# Количество столбцов в матрице 1: 2
# Количество строк в матрице 2: 2
# Количество столбцов в матрице 2: 3
# Вводим элементы матрицы A
# 11
# 1
# 1
# 1
# A =
# [11, 1]
# [1, 1]
# Вводим элементы матрицы B
# 2
# 3
# 4
# 5
# 3
# 2
# B =
# [2, 3, 4]
# [5, 3, 2]
# Результат:
# [27, 36, 46]
# [7, 6, 6]

# %%
2
