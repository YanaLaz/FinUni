# %%
my_tree1 = ['(','2','+','2',')']
my_tree2 = ['(','(', '2','+','3',')','*','4']

class resh():
    def main(my_tree):
        global rez
        rez = 0
        global tree
        tree = my_tree
        if tree[0]=='(':
           resh.new_branch(tree[1:])
        
    def new_branch(tree):
        print('new branch', tree)
        if tree[0].isdigit():
            if tree[1] == '+':
                resh.plus(tree)
            elif tree[1] == '*':
                resh.mult(tree)
        else:
            resh.new_branch(tree[1:])
            
    def plus(tree):
        print('plus', tree)
        rez = int(tree[0]) + int(tree[2])
        resh.check(tree[3:],rez)
        
    def mult(tree):
        print('mult', tree)
        rez = int(tree[0]) * int(tree[2])
        resh.check(tree[3:],rez)

    def check(tree,rez):
        print('check', tree)
        if len(tree) == 1:
            print(rez)
        else:
            resh.new_branch(tree)
            
            
resh.main(my_tree2)
# Out:
# new branch ['(', '2', '+', '3', ')', '*', '4']
# new branch ['2', '+', '3', ')', '*', '4']
# plus ['2', '+', '3', ')', '*', '4']
# check [')', '*', '4']
# new branch [')', '*', '4']
# new branch ['*', '4']
# new branch ['4']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-310b700bbe37> in <module>
#      39
#      40
# ---> 41 resh.main(my_tree2)
#
# <ipython-input-27-310b700bbe37> in main(my_tree)
#       9         tree = my_tree
#      10         if tree[0]=='(':
# ---> 11            resh.new_branch(tree[1:])
#      12
#      13     def new_branch(tree):
#
# <ipython-input-27-310b700bbe37> in new_branch(tree)
#      19                 resh.mult(tree)
#      20         else:
# ---> 21             resh.new_branch(tree[1:])
#      22
#      23     def plus(tree):
#
# <ipython-input-27-310b700bbe37> in new_branch(tree)
#      15         if tree[0].isdigit():
# ...

# %%
from random import randint 

class Node(object): 
    def __repr__(self): 
        return f"Это объект с ключом {self.root}" 
    
    def __init__ (self,root): 
        self.root= root 
        self.left= None 
        self.right= None 


    def printTree(start,traver): 
        if start: 
            traver = traver + (str(start.root))+"- " 
            traver= Node.printTree(start.left, traver) 
            traver = Node.printTree(start.right,traver) 
        return traver 

class Binary_Tree(object): 

    def __init__ (self, root): 
        self.root=Node(root) 


    def option (self, item): 
        if item=="1": 
            return self.TreePrint(tree.root) 
        
        elif item=="2": 
            return self.TaskTwo(tree.root) 

        elif item=="3": 
            return self.TaskThree(tree.root, 0) 

        elif item=="4": 
            return self.TaskFour(tree.root) 

        elif item=="5": 
            return self.TaskFive(tree.root) 


    def TaskFive(self,start): 
        if start: 
            if not start.right is None and start.right.root=="5" : 
                ka=int(start.right.root) 
                ba=int(start.left.root) 
                ka=ka-ba 
                a=tree.root.left.root 
                b=tree.root.right.right.root 
                pu=a*ka/b 
                print(pu) 
            else: 
                self.TaskFive(start.left) 
                self.TaskFive(start.right) 


    def TaskFour(self,start): 
        if start: 
            pic=start.right.right.root 
            dic=int(start.right.left.root) 
            click=start.left.root 
            ob=click*pic+dic 
            print (ob) 


    def TaskThree(self,start, su): 
        if start: 
            if not start.right is None and start.right.root=="*": 
                hook=start.right 
            if hook.right.root=="-": 
                hook=hook.right 
                a=int(hook.right.root) 
                b=int(hook.left.root) 
                su=a-b 
                tree.root.right.right=Node(su) 
                return self.TaskThree(start.left,su) 
            elif start.left.root=="+": 
                hook=start.left 
                a=int(hook.left.root) 
                b=int(hook.right.root) 
                kar=a+b 
                tree.root.left=Node(kar) 
                pan=su*kar 
                print (pan) 




    def TaskTwo(self,start): 
        if start: 
            if start.right.root=="*": 
                hook=start.right 
                c=int(hook.right.root) 
            if start.left.root=="+": 
                hook=start.left 
                a=int(hook.left.root) 
                b=int(hook.right.root) 
                su=(a+b)*c 
                print (su) 
            else: 
                self.TaskTwo(start.left) 
                self.TaskTwo(start.right) 



    def TreePrint(self,start): 
        if start: 
            if start.left.root=="+": 
                hook=start.left 
                a=int(hook.left.root) 
                b=int(hook.right.root) 
                su=a+b 
                print (su) 
            elif start.right.root=="+": 
                hook=start.right 
                a=int(hook.right.root) 
                b=int(hook.right.right) 
                su=a+b 
                print (su) 
            else: 
                self.TreePrint(start.left) 
                self.TreePrint(start.right) 

                
                


tree=Binary_Tree(1) 
tree.root.left=Node("+") 
tree.root.left.left=Node("2") 
tree.root.left.right=Node("2") 
a=Node.printTree(tree.root,"") 
print(a) 
tree.option("1") 

tree.root.left.right=Node("2") 
tree.root.left.left=Node("3") 
tree.root.right=Node("*") 
tree.root.right.right=Node("4") 
a=Node.printTree(tree.root,"") 
print(a) 
tree.option("2") 
tree.root.left=Node("lia") 

tree.root.left.left=Node("+") 
tree.root.left.left.left=Node("7") 
tree.root.left.left.right=Node("8") 
tree.root.right=Node("*") 
tree.root.right.right=Node("-") 
tree.root.right.right.right=Node("2") 
tree.root.right.right.left=Node("1") 
a=Node.printTree(tree.root,"") 
print(a) 
tree.option("3") 

tree.root.right.left=Node("7") 
a=Node.printTree(tree.root,"") 
print(a) 
tree.option("4") 
tree.root.right.right.right=Node("5") 
tree.root.right.right.left=Node("2") 
a=Node.printTree(tree.root,"") 
print(a) 
tree.option("5")
# Out:
# 1- +- 2- 2-
# 4
# 1- +- 3- 2- *- 4-
# 20
# 1- lia- +- 7- 8- *- -- 1- 2-
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-28-991649aca68c> in <module>
#     153 a=Node.printTree(tree.root,"")
#     154 print(a)
# --> 155 tree.option("3")
#     156
#     157 tree.root.right.left=Node("7")
#
# <ipython-input-28-991649aca68c> in option(self, item)
#      32
#      33         elif item=="3":
# ---> 34             return self.TaskThree(tree.root, 0)
#      35
#      36         elif item=="4":
#
# <ipython-input-28-991649aca68c> in TaskThree(self, start, su)
#      75                 su=a-b
#      76                 tree.root.right.right=Node(su)
# ---> 77                 return self.TaskThree(start.left,su)
#      78             elif start.left.root=="+":
#      79                 hook=start.left
#
# <ipython-input-28-991649aca68c> in TaskThree(self, start, su)
# ...

# %%
#задание №3
my_tree = ['A', ['B', ['D', '', ''],['E', ['G', '',''],'']],['C','', ['F', ['H','',''], ['I','','']]]]


test=True
def straight(el):
    global test
    if type(el) is not list and not test:
        return el
    else:
        test=False
        return el[0]+straight(el[1])+straight(el[2])
    
def postorder(el):
    global test
    if type(el) is not list and not test:
        return el
    else:
        test = False
        return postorder(el[1])+postorder(el[2])+el[0]
    
def inorder(el):
    global test
    if type(el) is not list and not test:
        return el
    else:
        test = False
        return inorder(el[1])+el[0]+inorder(el[2])

print('Прямой обход:',straight(my_tree))
print('Обратный обход:',postorder(my_tree))
print('Симметричный обход:',inorder(my_tree))
# Out:
# Прямой обход: ABDEGCFHI
# Обратный обход: DGEBHIFCA
# Симметричный обход: DBGEACHFI

# %%
#задание №3

class Node:
    def __init__(self, left=None, right=None, data=None):
        self.left = left
        self.right = right
        self.data = data

    def __str__(self):
        return str(self.data)

class Tree:
    def __init__(self, expression):
        self.root = None
        self.add(expression)

    def add(self, expression):
        token_list = list(''.join(expression))
        self.root = self._addToTree(token_list)

    def _addToTree(self, token_list):
        if token_list:
            brackets = 0
            index_sym = 0
            for inx, sym in enumerate(token_list):
                if sym == '(': brackets += 1
                if sym == ')': brackets -= 1
                if (sym != '(') and (sym != ')'): index_sym = inx
                if (brackets == 0) and (sym != ')') and (sym != '('):
                    index_sym = inx
                    break
            return Node(self._addToTree(token_list[1:index_sym]),
                        self._addToTree(token_list[index_sym+2:-1]),
                        token_list[index_sym])

    def InOrder(self):
        self._InOrder(self.root)

    def _InOrder(self, node):
        if (node != None):
            self._InOrder(node.left)
            print( str(node.data), end= ' ' )
            self._InOrder(node.right)

    def PreOrder(self):
        self._PreOrder(self.root)

    def _PreOrder(self, node):
        if (node != None):
            print( str(node.data), end= ' ' )
            self._PreOrder(node.left)
            self._PreOrder(node.right)

    def PostOrder(self):
        self._PostOrder(self.root)

    def _PostOrder(self, node):
        if (node != None):
            self._PostOrder(node.left)
            self._PostOrder(node.right)
            print( str(node.data), end= ' ' )

tree = Tree('((c)b(d))a(((g)f(h))e)')

print('Прямой обход')
tree.PreOrder()

print()
print('Концевой обход')
tree.PostOrder()

print()
print('Обратный обход')
tree.InOrder()
# Out:
# Прямой обход
# a b c d e f g h
# Концевой обход
# c d b g h f e a
# Обратный обход
# c b d a g f h e

# %% [markdown]
# Задача 4
# После выполнения программ, я заметила, что реализация поиска элемента по бинаронму дереву занимает больше времени, чем поиск элемента в массиве, и в то же время занимает меньше времени, чем поиск элемента в отсортированном массиве.

# %%
import array as ar
import timeit

tree =[81,[77,[79, 68, 10],[12, 13, 20] ],[15, [24, 27, 42],[33, 51, 57],]]
r=int(input('Введите число, которое ищите в дереве: '))

if r==tree[0]:
    print(f'Ваше число {r} есть в дереве')    
elif r in tree[1][1] or tree[1][2]:
    print(f'Ваше число {r} есть в дереве')
elif r in tree[2][1] or tree[2][2]:
    print(f'Ваше число {r} есть в дереве') 
else:
    print(f'Числа нет в дереве')
    
print(tree)
print('левая ветка = ', tree[1])
print('корень = ', tree[0])
print('правая ветка = ', tree[2])
art=timeit.default_timer()
len(tree)
print('Время на измерение длины поиска по дереву ', timeit.default_timer()-art)
# Out:
# Введите число, которое ищите в дереве: 77
# Ваше число 77 есть в дереве
# [81, [77, [79, 68, 10], [12, 13, 20]], [15, [24, 27, 42], [33, 51, 57]]]
# левая ветка =  [77, [79, 68, 10], [12, 13, 20]]
# корень =  81
# правая ветка =  [15, [24, 27, 42], [33, 51, 57]]
# Время на измерение длины поиска по дереву  0.00018388999887974933

# %%
# поиск в массиве 
arr = ar.array('i',[81, 77, 79, 68, 10, 12, 13, 20, 15, 24, 27, 42, 33, 51, 57])
r=int(input('Введите число, которое ищите в дереве: '))

if r in arr:
    print(f'Ваше число {r} есть в дереве')  

a=timeit.default_timer()
len(arr)
print('Время на измерение длины массива ', timeit.default_timer()-a)
# Out:
# Введите число, которое ищите в дереве: 77
# Ваше число 77 есть в дереве
# Время на измерение длины массива  0.0002972250003949739

# %%
#поиск по отсортированному массиву
ms=ar.array('i',[81, 77, 79, 68, 10, 12, 13, 20, 15, 24, 27, 42, 33, 51, 57])
sp = sorted(ms)
print(sp)

r=int(input('Введите число, которое ищите в дереве: '))

if r in sp:
    print(f'Ваше число {r} есть в дереве')  

a=timeit.default_timer()
len(sp)
print('Время на измерение длины массива ', timeit.default_timer()-a)
# Out:
# [10, 12, 13, 15, 20, 24, 27, 33, 42, 51, 57, 68, 77, 79, 81]
# Введите число, которое ищите в дереве: 77
# Ваше число 77 есть в дереве
# Время на измерение длины массива  0.0005718070005968912

# %%
trees =[21,[7,[5, [4,[2]],[6]],[14,[12,[9]], [18]]],[32, [27,[25,[24]], [30]],[37,[34,[33]], [39]]]]

class insert_key:      
    def start(tree, key):
        n = len(tree)
        if tree[0]<key:
            print('Идем вправо')
            insert_key.right(tree[2],key)
        else:
            print('Идем влево')
            insert_key.left(tree[1],key)
            
    def left(tree, key):
        if len(tree)>1:
            if tree[0]<key:
                print(tree[0],'<',key)
                print('tree[2]',tree[2])
                insert_key.right(tree[2],key)
            elif tree[0]>key:
                print(tree[0],'>',key)
                print('tree[1]',tree[1])
                insert_key.left(tree[1],key)
            else:
                print(tree)
        else:
            print(key)
            
    def right(tree, key):
        if len(tree)>1:
            if tree[0]<key:
                print(tree[0],'<',key)
                print('tree[2]',tree[2])
                insert_key.right(tree[2],key)
            elif tree[0]>key:
                print(tree[0],'>',key)
                print('tree[1]',tree[1])
                insert_key.left(tree[1],key)
            else:
                print(tree)
        else:
            print(key)
            
    def result(sp, key):
        
        
            
insert_key.start(trees, 3)
# Out:
# Идем влево
# 7 > 3
# tree[1] [5, [4, [2]], [6]]
# 5 > 3
# tree[1] [4, [2]]
# 4 > 3
# tree[1] [2]
# 3

# %%
find_index = 0

cou0 = 0 
def find_in(sp,key):
    global cou0
    print(sp)
    print(' ')
    if type(sp)!=int:
        for i in sp:
            cou0 += 1
            if i==key:
                print('YES')
                print('cou0',cou0)
                return key
            else:
                find_in(i,key)
       
            
                
find_in(trees, 2)
# Out:
# [21, [7, [5, [4, [2]], [6]], [14, [12, [9]], [18]]], [32, [27, [25, [24]], [30]], [37, [34, [33]], [39]]]]
#
# 21
#
# [7, [5, [4, [2]], [6]], [14, [12, [9]], [18]]]
#
# 7
#
# [5, [4, [2]], [6]]
#
# 5
#
# [4, [2]]
#
# 4
#
# [2]
#
# YES
# cou0 9
# [6]
#
# 6
#
# [14, [12, [9]], [18]]
#
# 14
#
# [12, [9]]
#
# 12
#
# [9]
#
# 9
#
# [18]
#
# 18
#
# [32, [27, [25, [24]], [30]], [37, [34, [33]], [39]]]
#
# 32
#
# [27, [25, [24]], [30]]
#
# 27
#
# [25, [24]]
#
# 25
#
# [24]
#
# 24
#
# [30]
#
# 30
#
# [37, [34, [33]], [39]]
#
# 37
#
# [34, [33]]
#
# 34
#
# [33]
#
# 33
#
# [39]
#
# 39

# %%
#задание 5 добавление элементов
class Node:

    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

    def insert(self, data):
# Сравниваем полученное значение с ключом родителя 
        if self.data:
            if data < self.data:
                if self.left is None:
                    self.left = Node(data)
                else:
                    self.left.insert(data)
            elif data > self.data:
                if self.right is None:
                    self.right = Node(data)
                else:
                    self.right.insert(data)
        else:
            self.data = data


    def PrintTree(self):
        if self.left:
            self.left.PrintTree()
        print( self.data),
        if self.right:
            self.right.PrintTree()

            
root = Node(21)
root.insert(7)
root.insert(32)
root.insert(5)
root.insert(14)
root.insert(27)
root.insert(37)
root.insert(4)
root.insert(6)
root.insert(12)
root.insert(18)
root.insert(25)
root.insert(30)
root.insert(34)
root.insert(39)
root.insert(2)
root.insert(9)
root.insert(24)
root.insert(33)

root.insert(38)
root.insert(20)
root.insert(8)
root.insert(13)
root.insert(47)



root.PrintTree()
